# %%
import json
import csv
from datetime import datetime
import time
import os
import requests
import re
import pandas as pd
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver import Chrome, ChromeOptions
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import threading
import random
import shutil

# %%
def scrape(sale_id):
    path = f"https://catalogue.astonbarclay.net/vehicle-search/?search=true&sites=1&sales={sale_id}"

    options = ChromeOptions()
    options.headless = False
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    driver.get(path)
    driver.maximize_window()

    # ✅ Accept cookie popup
    try:
        cookie = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.ID, "onetrust-accept-btn-handler"))
        )
        cookie.click()
    except:
        pass

    # ✅ Sync cookies into session
    cookies = driver.get_cookies()
    session = requests.Session()
    for cookie in cookies:
        session.cookies.set(cookie['name'], cookie['value'])

    # ✅ Check login status
    already_logged_in = False
    try:
        resp = session.get("https://catalogue.astonbarclay.net/api/user")
        if resp.status_code == 200:
            user = resp.json()
            if user.get("loggedIn"):
                already_logged_in = True
                print(f"🔒 Already logged in as {user.get('name')}")
    except:
        pass

    # ✅ Login if required
    if not already_logged_in:
        print("🔑 Logging in...")
        try:
            login_btn = WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.CSS_SELECTOR, ".acc_button_alt"))
            )
            login_btn.click()

            user_name = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "Username")))
            user_name.send_keys("sultanmirza0501@gmail.com")

            password = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "Password")))
            password.send_keys("Muhssan7865")

            submit_btn = driver.find_element(By.XPATH, "//input[@type='submit' and @value='Login']")
            submit_btn.click()

            print("✅ Logged in successfully.")
            time.sleep(5)
        except Exception as e:
            print(f"❌ Login step failed: {e}")

    # ✅ Fetch vehicle IDs
    cookies = driver.get_cookies()
    session.cookies.clear()
    for cookie in cookies:
        session.cookies.set(cookie['name'], cookie['value'])

    api_url = f"https://catalogue.astonbarclay.net/api/vehicle/all?siteid=1&saleid={sale_id}"
    response = session.get(api_url)
    if response.status_code == 200:
        data = response.json()
        ids = [item.get("id") for item in data.get("result", []) if "id" in item]

        filename = "aston_ids.json"
        if os.path.exists(filename):
            base_folder = "json"
            if os.path.exists(base_folder):
                random_suffix = str(random.randint(1000, 9999))
                base_folder = f"{base_folder}_{random_suffix}"

            os.makedirs(base_folder, exist_ok=True)
            filename = os.path.join(base_folder, "aston_ids.json")
        with open(filename, "w", encoding="utf-8") as f:
            json.dump({"count": len(ids), "ids": ids}, f, indent=4)

        print(f"✅ {len(ids)} IDs saved to '{filename}'")

    else:
        print(f"❌ Failed to fetch IDs — status {response.status_code}")

   
    return driver


def fetch_vehicle_details(driver):
    ids_file = "aston_ids.json"
    output_file = "aston_vehicles.json"

    if not os.path.exists(ids_file):
        print("❌ IDs file not found!")
        return

    with open(ids_file, "r", encoding="utf-8") as f:
        ids = json.load(f).get("ids", [])

    if not ids:
        print("❌ No IDs found.")
        return

    print(f"📦 Fetching {len(ids)} vehicle details...")

    all_vehicles = []

    for vid in tqdm(ids, desc="Fetching vehicles"):
        try:
            driver.execute_script(f"window.open('https://catalogue.astonbarclay.net/api/vehicle/details/{vid}?view=catalogue', '_blank');")
            driver.switch_to.window(driver.window_handles[-1])
            time.sleep(3)
            pre = driver.find_element(By.TAG_NAME, "pre")
            json_text = pre.text.strip()
            vehicle_data = json.loads(json_text)
            all_vehicles.append(vehicle_data)
            driver.close()
            driver.switch_to.window(driver.window_handles[0])
        except Exception as e:
            print(f"⚠️ Error fetching {vid}: {e}")
            if len(driver.window_handles) > 1:
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(all_vehicles, f, indent=4)

    print(f"✅ Saved {len(all_vehicles)} vehicles in '{output_file}'")


    driver.quit()



driver = scrape(17522)
fetch_vehicle_details(driver)
# Out:
# 🔑 Logging in...
# ✅ Logged in successfully.
# ✅ 64 IDs saved to 'json_9134\aston_ids.json'
# 📦 Fetching 106 vehicle details...
# Fetching vehicles:  39%|███▊      | 41/106 [02:10<03:27,  3.19s/it]
# ⚠️ Error fetching 116639291: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=141.0.7390.123); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0x12dfe43+66515]
# 	GetHandleVerifier [0x0x12dfe84+66580]
# 	(No symbol) [0x0x10cdc48]
# 	(No symbol) [0x0x10bce80]
# 	(No symbol) [0x0x10db81b]
# 	(No symbol) [0x0x1141c25]
# 	(No symbol) [0x0x115c4d9]
# 	(No symbol) [0x0x113afc6]
# 	(No symbol) [0x0x110c2ca]
# 	(No symbol) [0x0x110d154]
# 	GetHandleVerifier [0x0x1537353+2521315]
# 	GetHandleVerifier [0x0x15322d3+2500707]
# 	GetHandleVerifier [0x0x1307c94+229924]
# 	GetHandleVerifier [0x0x12f81f8+165768]
# 	GetHandleVerifier [0x0x12fecad+193085]
# 	GetHandleVerifier [0x0x12e8158+100072]
# 	GetHandleVerifier [0x0x12e82f0+100480]
# 	GetHandleVerifier [0x0x12d25aa+11066]
# 	BaseThreadInitThunk [0x0x759d7ba9+25]
# 	RtlInitializeExceptionChain [0x0x77ccc3ab+107]
# 	RtlClearBits [0x0x77ccc32f+191]
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 117, in fetch_vehicle_details(driver)
#     116 time.sleep(3)
# --> 117 pre = driver.find_element(By.TAG_NAME, "pre")
#     118 json_text = pre.text.strip()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:922, in WebDriver.find_element(self, by, value)
#     920     return elements[0]
# --> 922 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
#     453 if response:
# --> 454     self.error_handler.check_response(response)
#     455     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=141.0.7390.123); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0x12dfe43+66515]
# 	GetHandleVerifier [0x0x12dfe84+66580]
# 	(No symbol) [0x0x10cdc48]
# 	(No symbol) [0x0x10bce80]
# 	(No symbol) [0x0x10db81b]
# 	(No symbol) [0x0x1141c25]
# 	(No symbol) [0x0x115c4d9]
# 	(No symbol) [0x0x113afc6]
# 	(No symbol) [0x0x110c2ca]
# 	(No symbol) [0x0x110d154]
# 	GetHandleVerifier [0x0x1537353+2521315]
# 	GetHandleVerifier [0x0x15322d3+2500707]
# 	GetHandleVerifier [0x0x1307c94+229924]
# 	GetHandleVerifier [0x0x12f81f8+165768]
# 	GetHandleVerifier [0x0x12fecad+193085]
# 	GetHandleVerifier [0x0x12e8158+100072]
# 	GetHandleVerifier [0x0x12e82f0+100480]
# 	GetHandleVerifier [0x0x12d25aa+11066]
# 	BaseThreadInitThunk [0x0x759d7ba9+25]
# 	RtlInitializeExceptionChain [0x0x77ccc3ab+107]
# 	RtlClearBits [0x0x77ccc32f+191]
#
#
# During handling of the above exception, another exception occurred:
#
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 140
#     135     driver.quit()
#     139 driver = scrape(17522)
# --> 140 fetch_vehicle_details(driver)
#
# Cell In[2], line 125, in fetch_vehicle_details(driver)
#     123 except Exception as e:
#     124     print(f"⚠️ Error fetching {vid}: {e}")
# --> 125     if len(driver.window_handles) > 1:
#     126         driver.close()
#     127         driver.switch_to.window(driver.window_handles[0])
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:636, in WebDriver.window_handles(self)
#     628 @property
#     629 def window_handles(self) -> list[str]:
#     630     """Returns the handles of all windows within the current session.
#     631
#     632     Example:
#     633     --------
#     634     >>> print(driver.window_handles)
#     635     """
# --> 636     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
#     451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
# --> 454     self.error_handler.check_response(response)
#     455     response["value"] = self._unwrap_value(response.get("value", None))
#     456     return response
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0x12dfe43+66515]
# 	GetHandleVerifier [0x0x12dfe84+66580]
# 	(No symbol) [0x0x10cda6b]
# 	(No symbol) [0x0x110b5ab]
# 	(No symbol) [0x0x113b086]
# 	(No symbol) [0x0x113667c]
# 	(No symbol) [0x0x1135bf3]
# 	(No symbol) [0x0x109e72d]
# 	(No symbol) [0x0x109ecae]
# 	(No symbol) [0x0x109f14d]
# 	GetHandleVerifier [0x0x1537353+2521315]
# 	GetHandleVerifier [0x0x15322d3+2500707]
# 	GetHandleVerifier [0x0x1307c94+229924]
# 	GetHandleVerifier [0x0x12f81f8+165768]
# 	GetHandleVerifier [0x0x12fecad+193085]
# 	(No symbol) [0x0x109e3e3]
# 	(No symbol) [0x0x109db60]
# 	GetHandleVerifier [0x0x167c20f+3852191]
# 	BaseThreadInitThunk [0x0x759d7ba9+25]
# 	RtlInitializeExceptionChain [0x0x77ccc3ab+107]
# 	RtlClearBits [0x0x77ccc32f+191]

# %%
input_file = "aston_vehicles.json"
output_file = "barclay_renamed.csv"

headers = [
    "Title", "Derivative", "Images", "Auction Availability", "Lot", "Start Time", "Start Date",
    "Center", "Auction ID", "D.O.R", "Reg", "Mileage", "Mileage warranted", "Colour", "Body type",
    "Doors", "Fuel Type", "Transmission", "V5", "MOT Expiry Date", "CO2 emissions", "VAT status",
    "Former keepers", "Non Runner", "Vendor", "Service History", "Service Notes", "No of Service",
    "Last Service", "Last service mileage", "Grade", "CAP clean", "Euro Status", "CAP retail",
    "CAP average", "CAP below", "Autotrader Retail Value", "Autotrader Trade Value", "Powered by",
    "Inspection date", "VIN", "Exterior grade", "Interior grade", "Make", "Model", "CC",
    "Engine number", "Body plan", "Gearbox", "Paint type", "Colour Trim", "Seats",
    "Date of first reg", "Keys", "Inspection Report", "Other Report", "Tyres", "Spare Tyre",
    "Equipment", "Damaged_images", "Damage_details", "Year"
]

# ✅ Helper functions
def safe_list(val):
    if isinstance(val, (list, tuple)):
        return list(val)
    elif isinstance(val, str):
        return [val]
    return []

def safe_dict(val):
    return val if isinstance(val, dict) else {}

def safe_str(val):
    return str(val) if val is not None else ""

def format_datetime(dt_str):
    if not dt_str:
        return ""
    try:
        dt = datetime.fromisoformat(str(dt_str).replace("Z", "+00:00"))
        return dt.strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return ""

# ✅ Load JSON
with open(input_file, "r", encoding="utf-8") as f:
    vehicles = json.load(f)

# ✅ Write CSV
with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=headers)
    writer.writeheader()

    for v in vehicles:
        v = safe_dict(v)
        inspection = safe_dict(v.get("inspection"))
        tyres = safe_dict(inspection.get("tyres"))
        vat_status = safe_dict(v.get("vatStatus"))
        site = safe_dict(v.get("site"))

        # ✅ Safe service extraction
        service_str = safe_str(v.get("serviceHistory"))
        entries = re.findall(
            r"(?:Service\s*(?:book|digital|invoice|print)?\s*)?(\d{2}/\d{2})\s*-\s*([\d,.Kk]+)",
            service_str
        )

        # ✅ Safe Start Date
        start_date_str = safe_str(v.get("saleStart"))

        # ✅ Build row
        row = {
            "Title": f"{safe_str(v.get('make'))} {safe_str(v.get('model'))}".strip(),
            "Derivative": safe_str(v.get("derivative")),
            "Images": ", ".join(safe_list(v.get("images"))),
            "Auction Availability": "Available" if not v.get("virtual", False) else "Virtual",
            "Lot": safe_str(v.get("lot")),
            "Start Time": (
                datetime.fromisoformat(start_date_str.replace("Z", "+00:00")).strftime("%H:%M")
                if start_date_str else ""
            ),
            "Start Date": format_datetime(start_date_str)[:10],
            "Center": safe_str(site.get("name")),
            "Auction ID": safe_str(v.get("saleId")),
            "D.O.R": safe_str(v.get("firstRegistration")),
            "Reg": safe_str(v.get("registration")),
            "Mileage": safe_str(v.get("mileage")),
            "Mileage warranted": safe_str(v.get("mileageWarranty")),
            "Colour": safe_str(v.get("colour")),
            "Body type": safe_str(v.get("bodyType")),
            "Doors": safe_str(v.get("doors")),
            "Fuel Type": safe_str(v.get("fuel")),
            "Transmission": safe_str(v.get("transmission")),
            "V5": safe_str(v.get("v5")),
            "MOT Expiry Date": safe_str(v.get("motExpiry")),
            "CO2 emissions": safe_str(v.get("co2")),
            "VAT status": safe_str(vat_status.get("label")),
            "Former keepers": safe_str(v.get("formerKeepers")),
            "Non Runner": safe_str(v.get("nonRunner")),
            "Vendor": safe_str(v.get("seller")),
            "Service History": service_str,
            "Service Notes": safe_str(v.get("remarks")),
            "No of Service": len(entries) if entries else "",
            "Last Service": entries[-1][0] if entries else "",
            "Last service mileage": entries[-1][1] if entries else "",
            "Grade": safe_str(v.get("namaGrade")),
            "CAP clean": safe_str(v.get("capCleanPrice")),
            "Euro Status": safe_str(v.get("eurostatus")),
            "CAP retail": safe_str(v.get("capRetailPrice")),
            "CAP average": safe_str(v.get("capAveragePrice")),
            "CAP below": safe_str(v.get("capUsedBelow")),
            "Autotrader Retail Value": safe_str(v.get("deltapointRetailPrice")),
            "Autotrader Trade Value": safe_str(v.get("deltapointTradePrice")),
            "Powered by": safe_str(v.get("assuredType")),
            "Inspection date": safe_str(inspection.get("date")).split("T")[0] if inspection.get("date") else "",
            "VIN": safe_str(v.get("vin")),
            "Exterior grade": "",
            "Interior grade": "",
            "Make": safe_str(v.get("make")),
            "Model": safe_str(v.get("model")),
            "CC": float(v.get("engineSize", 0)) / 100 if v.get("engineSize") else "",
            "Engine number": "",
            "Body plan": safe_str(v.get("bodyType")),
            "Gearbox": safe_str(v.get("transmission")),
            "Paint type": "",
            "Colour Trim": safe_str(inspection.get("interiorTrim")),
            "Seats": safe_str(inspection.get("seats")),
            "Date of first reg": safe_str(v.get("firstRegistration")),
            "Keys": safe_str(inspection.get("keys")),
            "Inspection Report": safe_str(inspection.get("uncostedreporturl")),
            "Other Report": safe_str(v.get("assuredUrl")),
            "Tyres": ", ".join(
                f"{name}: {safe_str(value)}"
                for name, value in {
                    "NSF": tyres.get("nsf"),
                    "OSF": tyres.get("osf"),
                    "OSR": tyres.get("osr"),
                    "NSR": tyres.get("nsr"),
                    "Spare": tyres.get("spare"),
                }.items()
                if value not in ("", None)
            ),
            "Spare Tyre": safe_str(tyres.get("spare")),
            "Equipment": ", ".join(
                safe_str(opt.get("description"))
                for opt in safe_list(inspection.get("options"))
                if opt.get("description")
            ),
            "Damaged_images": ", ".join(
                safe_str(img)
                for d in safe_list(inspection.get("damage"))
                for img in safe_list(d.get("images"))
            ),
            "Damage_details": "; ".join(
                f"{safe_str(d.get('component'))} – {safe_str(d.get('damage'))}"
                for d in safe_list(inspection.get("damage"))
                if d.get("component") or d.get("damage")
            ),
            "Year": safe_str(v.get("firstRegistration"))[:4],
        }

        writer.writerow({h: row.get(h, "") for h in headers})

print(f"✅ CSV created successfully: {output_file}")
# Out:
# ✅ CSV created successfully: barclay_renamed.csv

# %%
#     # create a driver using chrome
#     driver = Chrome(service=service, options=options)
#     # run the driver through url
#     driver.get(path)
#     driver.maximize_window()
    

# # =====================================================================================
#     # handle cookies
# # =====================================================================================
#     try:
#         # time.sleep(1)
#         cookie = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.XPATH, './/button[@id = "onetrust-accept-btn-handler"]')))
#         if cookie:
#             cookie.click()
#         else:
#             pass
#     except Exception as e:
#         print("No cookies tab found")


# # =====================================================================================
#     # get the login icon and click on it 
# # =====================================================================================
#     try:
#         # get the login button
#         login = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, ".acc_button_alt")))
#         if login:
#             driver.execute_script("arguments[0].scrollIntoView();", login)
#             login.click()
#         else:
#             pass

#     except Exception as e:
#         print(f"No login tab found")

# # =====================================================================================
#     # complete logiin info
# # =====================================================================================

#     # get the username tab
#     try:
#         provided_u_name = "sultanmirza0501@gmail.com"
#         user_name = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.ID,"Username")))   
#         user_name.send_keys(provided_u_name)
#     except Exception as e:
#         print(f"No username tab found")

#     # get password tab
#     try:
#         provided_pass = "Muhssan7865"
#         password = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.ID, "Password")))
#         password.send_keys(provided_pass)
#     except Exception as e:
#         print(f"No password tab found")

#     # get the login tab to enter the username and password
#     try:
#         # login_tab_css = "submit"
#         login_tab = driver.find_element(By.XPATH,  "//input[@type='submit' and @value='Login']")
#         driver.execute_script("arguments[0].scrollIntoView();", login_tab)
#         login_tab.click()
#         for i in range(2):
#             driver.back()
#     except Exception as e:
#         print(f"No login tab found")

# # =====================================================================================
#     # handle cookies
# # =====================================================================================
#     # try:
#     #     cookie = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.ID, "onetrust-accept-btn-handler")))
#     #     if cookie:
#     #         cookie.click()
#     #     else:
#     #         pass
#     # except Exception as e:
#     #     print("No cookies tab found")

# # =====================================================================================
#     # get only number
# # =====================================================================================
#     try:
#         import time
#         time.sleep(2)
#         num_cars = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, ".d-md-flex span"))).text
#         cars_list = num_cars.split(" ")
#         cars =  int(cars_list[1]) # get only number
#         print(f"Number {cars} of cars found")
#     except Exception as e:
#         print(f"No number of cars found")

# # =====================================================================================
#     # get the car link and click on it to proceed to main car information page
# # =====================================================================================
#     try:
#         link = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, ".vehicle-card-header")))
#         if link:
#         # now we have to click on the link to get the main car info page
#             driver.execute_script("arguments[0].scrollIntoView();", link)
#             link.click()
#         else:
#             pass
#     except Exception as e:
#         print(f"No link found")
# # =====================================================================================  


# # =====================================================================================
#     # loop around the number of images present
# # =====================================================================================

#     results = [] # to append the dict values later on
#     for i in range(cars):# we will make use of number of pages here
#         if not driver.window_handles:
#             print("Browser window closed. Stopping script.")
#             break

#     # ===================================================================================== 
#         # get the name of the car
#     # =====================================================================================
#         details = {}
        
#         try:
#             # Wait for car title element to appear (it can be <h2> or <h1>)
#             car_name_el = WebDriverWait(driver, 10).until(
#                 EC.presence_of_element_located((
#                     By.CSS_SELECTOR,
#                     "h2.vehicle-description-title, h1.vehicle-description, .ab-catelogue-vehicle-details-header h2"
#                 ))
#             )
#             car_name = car_name_el.text.strip()

#             if car_name:
#                 details["Title"] = car_name
#                 parts = car_name.split(" - ")
#                 if len(parts) > 1:
#                     description = parts[1].strip()
#                     words = description.split()
#                     index = next((i for i, w in enumerate(words) if any(ch.isdigit() for ch in w)), None)
#                     if index is not None and index + 1 < len(words):
#                         derivative = " ".join(words[index+1:])
#                         details["Derivative"] = derivative
#                     else:
#                         details["Derivative"] = "N/A"
#                 else:
#                     details["Derivative"] = "N/A"
#             else:
#                 details["Title"] = "No car name found"
#                 details["Derivative"] = "N/A"

#         except Exception as e:
#             print(f"❌ Error extracting car name: {e}")


        
#     # ===================================================================================== 
#         # extract the car images 
#     # =====================================================================================
#         try:
#             images=[]
#             # import time
#             time.sleep(2)
#             img_main =WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR, "ul.slider.animated"))) 
#             imgs = WebDriverWait(img_main, 3).until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "li.slide img")))
#             # driver.find_elements(By.CSS_SELECTOR, "li.slide img")

#             for img in imgs:
#                 images.append(img.get_attribute("src"))

#             imgs_str = ", ".join(images)
#             details['Images'] = imgs_str

#         except Exception as e:
#             print(f"No images found")

#     # =====================================================================================         
#         # get the lot time, date, auction and center fields
#     # =====================================================================================
#         try:
#             # container_selector = ".ab-catelogue-vehicle-details-auction-details"
#             container = driver.find_element(By.CSS_SELECTOR, ".ab-catelogue-vehicle-details-auction-details")

#             # Extract Auction Availability
#             auction_availability = container.find_element(By.TAG_NAME, "p").text
#             if auction_availability:
#                 details["Auction Availability"] = auction_availability
#             else:
#                 details["Auction Availability"] = "No auction availability found"

#             # Extract Lot, Time, and Date
#             lot_time_date = container.find_elements(By.CSS_SELECTOR, "h3 span")
#             if lot_time_date:
#                 lot = lot_time_date[0].text.replace("Lot: ", "")  # Removing 'Lot: ' prefix
#                 start_time = lot_time_date[1].text
#                 date = lot_time_date[2].text
#                 details['Lot'] = lot
#                 details['Start Time']= start_time
#                 details['Start Date'] = date
#             else:
#                 details['Lot'] = "na"
#                 details['Start Time']= "na"
#                 details['Start Date'] = "na"


#             # Extract Center
#             center = container.find_element(By.CSS_SELECTOR, "h3:nth-of-type(2) span").text.strip()
#             if center:
#                 details["Center"] = center.split("(")[0]
#                 details['Auction ID'] = center.split("(")[1].split(")")[0]
#             else:
#                 details['Center'] = "No center found"
#                 details['Auction ID'] = 'na'

#         except Exception as e:
#             print(f"Nothing found")
        
#     # =====================================================================================
#         # get the vehicle details
#     # =====================================================================================
#         try:
#             # click on vehicle tab
#             veh_tab = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.LINK_TEXT, "VEHICLE")))
#             if veh_tab:
#                 driver.execute_script("arguments[0].scrollIntoView();", veh_tab)
#                 veh_tab.click()

#                 base_card = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.XPATH, './/div[@class="tab-content"]')))
                
#                 # Locate the table inside the card
#                 table_selector = ".tab-pane.active .table tbody tr"
#                 rows = base_card.find_elements(By.CSS_SELECTOR, table_selector)
                
#                 if rows:
#                     for row in rows:
#                         # Find all <td> elements in the row
#                         tds = row.find_elements(By.TAG_NAME, "td")
#                         if len(tds) == 2:  # Ensure there are exactly two <td> elements
#                             label = tds[0].text.strip()

#                             # Special case for "Mileage warranted"
#                             if label == "Mileage warranted" or label == "V5":
#                                 try:
#                                     path_element = tds[1].find_element(By.TAG_NAME, "path")
#                                     value = path_element.get_attribute("d")  # Get the 'd' attribute
#                                 except Exception as e:
#                                     value = "Path not found"
#                             else:
#                                 value = tds[1].text.strip()

#                             details[label] = value
#                 else:
#                     print("No rows found")
                
#             else:
#                 print("No vehicle tab found")
#         except Exception as e:
#             print(f"Novehcile info found")

#     # =====================================================================================
#         # get the valuations
#     # =====================================================================================
#         try:

#             valuation = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.LINK_TEXT, "VALUATIONS")))
#             if valuation:
#                 driver.execute_script("arguments[0].scrollIntoView();", valuation)
#                 valuation.click()
#                 import time
#                 time.sleep(1)

#                 val_card = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CLASS_NAME, "tab-content")))
#                 if val_card:
#                     val_rows = val_card.find_elements(By.CSS_SELECTOR, ".tab-pane.active .table tbody tr")
#                     if val_rows:         
#                         for val_row in val_rows:
#                             # Find all <td> elements in the row
#                             val_tds = val_row.find_elements(By.TAG_NAME, "td")
#                             if len(tds) == 2:  # Ensure there are exactly two <td> elements
#                                 val_label = val_tds[0].text.strip()
#                                 val_value = val_tds[1].text.strip()
#                                 details[val_label] = val_value
#                     else:
#                         print("No value rows found inside valaution card")
#                 else:
#                     print("No valuation card found")
#             else:
#                 print("No valaution button found")

#         except Exception as e:
#             print(f"No valaution button found")
        
#     # =====================================================================================
#         # get the INSPECTION REPORT
#     # =====================================================================================
#         try:

#             inspection = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.LINK_TEXT, "INSPECTION REPORT")))
#             if inspection:
#                 driver.execute_script("arguments[0].scrollIntoView();", inspection)
#                 inspection.click()
#                 import time
#                 time.sleep(1)
            
#                 # Now extract the fields inside the inspection report
#                 inspec_card = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CLASS_NAME, "tab-content")))
#                 if inspec_card:
#                     insp_rows = inspec_card.find_elements(By.CSS_SELECTOR, ".tab-pane.active .table tbody tr")
#                     if insp_rows:         
#                         for insp_row in insp_rows:
#                             # Find all <td> elements in the row
#                             insp_tds = insp_row.find_elements(By.TAG_NAME, "td")
#                             if len(insp_tds) == 2:  # Ensure there are exactly two <td> elements
#                                 insp_label = insp_tds[0].text.strip()
#                                 insp_value = insp_tds[1].text.strip()
#                                 details[insp_label] = insp_value
#                     else:
#                         print("No value rows found inside valaution card")
#                 else:
#                     print("No valuation card found")
            
#             # =====================================================================================
#                 # get the icon image link at the side of the name of the car
#             # =====================================================================================
#                 try:
#                     # inspec_rep_css = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.XPATH, "//a[text()='Download the inspection report']")))
#                     inspec_rep_css = driver.find_element(By.XPATH, "//a[text()='Download the inspection report']")
#                     if inspec_rep_css:
#                         inspec_link = inspec_rep_css.get_attribute('href')
#                         details["Inspection Report"] =  inspec_link
#                     else:
#                         details["Inspection Report"] = "No inspection report found"
#                 except Exception as e:
#                     print("No car inspection report tab found")

#             # ===================================================================================== 
#                 # get the assured report link at the side of the name of the car
#             # =====================================================================================
#                 try:
#                     icon_image_link = inspec_card.find_element(By.XPATH, "//a[contains(@href, '.pdf')]")

#                     if icon_image_link:
#                         icon_href = icon_image_link.get_attribute("href")
#                         details['Other Report'] = icon_href
#                     else:
#                         details['Other Report'] = "N/A"
#                 except Exception as e:
#                     print(f"No icon image tab found")

                
#                 # tyres
#                 try:
#                     tyre_main = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.XPATH, './/h3[contains(text(), "Tyres")]//following::table[1]')))
#                     if tyre_main:
#                         tyre_trs = WebDriverWait(tyre_main, 3).until(EC.presence_of_all_elements_located((By.TAG_NAME, 'tr')))
#                         if tyre_trs:
#                             for tyre_tr in tyre_trs:
#                                 tyre_lbl = tyre_tr.find_elements(By.TAG_NAME, "td")
#                                 if tyre_lbl:
#                                     details[tyre_lbl[0].text.strip()] = [tyre_lbl[1].text.strip(), tyre_lbl[2].text.strip()]
#                         else:
#                             print("No interior")
#                 except:
#                     print(f"No tyre data")
#             else:
#                 print("No inspection button found")
#         except Exception as e:
#             print(f"No inspection button found")
        
#     # =====================================================================================
#         # get the SPECIFICATION
#     # =====================================================================================
#         try:
#             # get the button and then click on it
#             spec_text = "SPECIFICATION"
#             specs = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.LINK_TEXT, spec_text)))
#             if specs:
#                 driver.execute_script("arguments[0].scrollIntoView();", specs)
#                 specs.click()
#                 import time
#                 time.sleep(1)

#                 # now extract the fields inside valautions
#                 spec_card_class = "tab-content"
#                 spec_card = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.CLASS_NAME, spec_card_class)))
                
#                 # Locate the table inside the card
#                 spec_table_selector = ".tab-pane.active .table tbody tr"
#                 spec_rows = spec_card.find_elements(By.CSS_SELECTOR, spec_table_selector)
                
#                 td_texts = [td.text for td in spec_rows if td.text.strip() != ""]
#                 details['Equipment']=td_texts
#             else:
#                 print("No specs button found")
#         except Exception as e:
#             print(f"No specification button found")


#     # =====================================================================================
#         # Extract the image source URL
#     # =====================================================================================
#         try:
#             damage_text = "DAMAGE REPORT"
#             damages = WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.LINK_TEXT, damage_text)))
#             if damages:
#                 driver.execute_script("arguments[0].scrollIntoView();", damages)
#                 damages.click()
#                 import time
#                 time.sleep(1)

#                 # Initialize list for storing damaged image URLs and key-value pairs
#                 damaged_list = []
#                 details_list = []

#                 # Extract all image elements with the class 'magnifier-image'
#                 img_elements = driver.find_elements(By.CLASS_NAME, 'magnifier-image')
#                 for img in img_elements:
#                     damaged_list.append(img.get_attribute("src"))
                
#                 # Assuming there's only one image to focus on for now
#                 damaged_urls = ", ".join(damaged_list)
#                 details["Damaged_images"] = damaged_urls

#                 # Extract key-value pairs from the damage table
#                 damage_rows = driver.find_elements(By.CSS_SELECTOR, '.tab-pane.active .table tbody tr')

#                 for damage_row in damage_rows:
#                     # Get the first and second <td> elements
#                     columns = damage_row.find_elements(By.TAG_NAME, 'td')
#                     if len(columns) >= 2:  # Ensure there are exactly two columns
#                         column_name = columns[0].text.strip()
#                         column_value = columns[1].text.strip()
#                         details_list.append({column_name: column_value})

#                 details["Damage_details"] = details_list  # Add to the 'details' dictionary
#             else:
#                 print("No damage button found")
#         except Exception as e:
#             print(f"No damage button found")
#     # =====================================================================================
#     # =====================================================================================

#         # append the in the results 
#         results.append(details)

#     # =====================================================================================
#         # get the next button
#     # =====================================================================================
#         try:
#             next_button = driver.find_element(By.CSS_SELECTOR, "a.vehicle-details-btn-next")
#             if next_button:
#                 # get the link
#                 # car_page_link = next_button.get_attribute("href")
#                 # details['Car_link']= car_page_link
#                 next_button.click()
#             else:
#                 # details['Car_link'] = "N/A"
                
#                 break
#         except Exception as e:
#             print("No next button found hence no more cars are available")

# # =====================================================================================
#     # create a dataframe 
#     df = pd.DataFrame.from_dict(results)
#     df.to_csv("Barclay_data.csv", index=False)

#     driver.quit()

# # call the function
# path = "https://catalogue.astonbarclay.net/vehicle-search/?search=true&sites=1&sales=17524"
# scrape(path)

# %%
# df=pd.read_csv("Barclay_data.csv")
# df.rename(columns={"REG":"Reg", "Fuel":"Fuel Type", "MOT expires":"MOT Expiry Date", "Service":"Service History", "Notes":"Service Notes", "NAMA grade":"Grade", "CAP clean price":"CAP clean", "CAP retail price":"CAP retail", "CAP average price":"CAP average", "CAP below price":"CAP below", "Current retail value":"Autotrader Retail Value", "Current trade value":"Autotrader Trade Value", "NSF":"Tyre NSF", "OSF":"Tyre OSF", "NSR":"Tyre NSR", "OSR":"Tyre OSR", "Spare":"Spare Tyre", "Internal grade":"Interior grade", "D.O.R.":"D.O.R", "Int. colour trim":"Colour Trim", "Seller":"Vendor", "CN":"VIN", "Engine size":"CC"}, inplace=True)
# df['Year'] = df['D.O.R'].apply(lambda x : x.split("/")[-1] if isinstance(x, str) and "/" in x else "na")
# df['Last Service'] = df['Service History'].apply(lambda x : f"02/" + x.split(" ")[-1].split("-")[0] if isinstance(x, str) and " "in x and "-" in x else 'na')
# df['Last Service Mileage'] = df['Service History'].apply(lambda x : x.split(" ")[-1].split(",")[0].split("-")[-1] if isinstance(x, str) and " " in x and "," in x and "-" in x else 'na')

# df['CC'] = df['CC'].replace('-', 0).astype(int)

# df['CC'] = df['CC'].apply(lambda x : float(x/1000) if x else "na")

# df.to_csv("barclay_renamed.csv", index=False)
# os.remove("Barclay_data.csv")

# %% [markdown]
# ### images and reports

# %%
from PIL import Image, ImageDraw, ImageFont
def add_watermark_to_image(image_path, text="Sourced from Aston Barclays"):
    try:
        image = Image.open(image_path).convert("RGBA")
        txt_layer = Image.new("RGBA", image.size, (255, 255, 255, 0))
        draw = ImageDraw.Draw(txt_layer)

        # Load font
        try:
            font = ImageFont.truetype("arial.ttf", 16)
        except:
            font = ImageFont.load_default()

        # Calculate text size and position
        margin = 10
        bbox = draw.textbbox((0, 0), text, font=font)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]
        x = image.width - text_width - margin
        y = image.height - text_height - margin

        # Draw semi-transparent background box
        box_width = text_width + 2 * margin
        box_height = text_height + 2 * margin
        draw.rectangle([x - margin, y - margin, x - margin + box_width, y - margin + box_height],fill=(0, 0, 0, 160))

        # Draw watermark text
        draw.text((x, y), text, font=font, fill=(255, 255, 255, 200))

        # Merge and save
        watermarked = Image.alpha_composite(image, txt_layer).convert("RGB")
        watermarked.save(image_path)
        print(f"Watermark added to {image_path}")

    except Exception as e:
        print(f"Failed to watermark {image_path}: {e}")

# %%
from urllib.parse import urlparse, urljoin

df = pd.read_csv("barclay_renamed.csv")

reg_img = df[['Reg', "Images", "Damaged_images"]]
reports = df[['Reg', "Inspection Report","Other Report"]]


def download_images(data, main_folder="Images"):

    os.makedirs(main_folder, exist_ok=True)
    

    for index, row in data.iterrows():
        reg_no = row["Reg"] 
        
     
        image_urls = row["Images"].split(", ") if pd.notna(row["Images"]) else []
        damaged_urls = row["Damaged_images"].split(", ") if pd.notna(row["Damaged_images"]) else []
        
   
        reg_folder = os.path.join(main_folder, reg_no) 
        os.makedirs(reg_folder, exist_ok=True)  
       
        images_folder = os.path.join(reg_folder, "Original_images") 
        os.makedirs(images_folder, exist_ok=True)  

       
        damaged_folder = os.path.join(reg_folder, "Damaged_images")  
        os.makedirs(damaged_folder, exist_ok=True)  

   
        for idx, url in enumerate(image_urls):
            url = url.strip()  
            if not url.startswith(("http://", "https://")):  
                url = urljoin("https://", url)  

        
            parsed_url = urlparse(url)

    
            if not parsed_url.scheme or not parsed_url.netloc:
                print(f"Invalid URL skipped: {url}")
                continue
            

            try:
     
                response = requests.get(url, stream=True)
                response.raise_for_status() 

                file_name = os.path.basename(parsed_url.path) or f"image_{idx + 1}.jpg"

         
                file_extension = file_name.split(".")[-1]
                if file_extension not in ["jpg", "jpeg", "png", "gif", "bmp", "webp"]:
                    file_name = f"image_{idx + 1}.jpg"  
                
              
                full_file_name = os.path.join(images_folder, f"{reg_no}_{idx + 1}.jpg")
                
          
                with open(full_file_name, 'wb') as f:
                    for chunk in response.iter_content(1024):
                        f.write(chunk)

            
                add_watermark_to_image(full_file_name)
                
                print(f"Downloaded: {full_file_name}")
            except Exception as e:
                print(f"Failed to download {url} for {reg_no}: {e}")

   
        for idx, url in enumerate(damaged_urls):
            url = url.strip()  
            if not url.startswith(("http://", "https://")):
                url = urljoin("https://", url)  

         
            parsed_url = urlparse(url)

     
            if not parsed_url.scheme or not parsed_url.netloc:
                print(f"Invalid URL skipped: {url}")
                continue
            
  
            try:
          
                response = requests.get(url, stream=True)
                response.raise_for_status()  

    
                file_name = os.path.basename(parsed_url.path) or f"damaged_{idx + 1}.jpg"

        
                file_extension = file_name.split(".")[-1]
                if file_extension not in ["jpg", "jpeg", "png", "gif", "bmp", "webp"]:
                    file_name = f"damaged_{idx + 1}.jpg"  
                
          
                full_file_name = os.path.join(damaged_folder, f"{reg_no}_{idx + 1}.jpg")
                
         
                with open(full_file_name, 'wb') as f:
                    for chunk in response.iter_content(1024):
                        f.write(chunk)

          
                add_watermark_to_image(full_file_name)

                
                print(f"Downloaded: {full_file_name}")
            except Exception as e:
                print(f"Failed to download {url} for {reg_no}: {e}")


def download_reports(data, main_folder="Reports"):
    os.makedirs(main_folder, exist_ok=True)

    for i, row in data.iterrows():
        reg_no = str(row["Reg"]).strip()
        inspection_url = row["Inspection Report"]
        other_url = row["Other Report"]

        # Folder for this vehicle
        vehicle_folder = os.path.join(main_folder, reg_no)
        os.makedirs(vehicle_folder, exist_ok=True)

        # Subfolders
        inspection_folder = os.path.join(vehicle_folder, "Inspection Report")
        other_folder = os.path.join(vehicle_folder, "Other Report")
        os.makedirs(inspection_folder, exist_ok=True)
        os.makedirs(other_folder, exist_ok=True)

        # --- Helper Function for Download ---
        def download_file(url, dest_folder, file_label):
            if not url or pd.isna(url):
                print(f"❌ Missing {file_label} for {reg_no}")
                return
            
            if not url.startswith(("http://", "https://")):
                url = urljoin("https://", url)

            parsed = urlparse(url)
            if not parsed.scheme or not parsed.netloc:
                print(f"⚠️ Invalid URL skipped for {reg_no}: {url}")
                return

            try:
                response = requests.get(url, stream=True, timeout=15)
                response.raise_for_status()
                file_path = os.path.join(dest_folder, f"{reg_no}.pdf")

                with open(file_path, "wb") as f:
                    for chunk in response.iter_content(1024):
                        f.write(chunk)

                print(f"✅ Downloaded {file_label} for {reg_no}")
            except Exception as e:
                print(f"❌ Failed {file_label} for {reg_no}: {e}")

        # Download both reports
        download_file(inspection_url, inspection_folder, "Inspection Report")
        download_file(other_url, other_folder, "Other Report")

    print("🎉 All reports processed.")


def start_funcs():
    thread1 = threading.Thread(target=download_images, args=(reg_img,))
    thread2 = threading.Thread(target=download_reports, args=(reports,))
    
    # start threads 
    thread1.start()
    thread2.start()

    # join threads
    thread1.join()
    thread2.join()
    
if __name__ == "__main__":
    start_funcs()
# Out:
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_1.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_1.jpg
# ✅ Downloaded Inspection Report for EA17HKK
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_2.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_2.jpg
# ✅ Downloaded Other Report for EA17HKK
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_3.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_3.jpg
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_4.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_4.jpg
# ✅ Downloaded Inspection Report for DU67TZV
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_5.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_5.jpg
# ✅ Downloaded Other Report for DU67TZV
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_6.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_6.jpg
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_7.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_7.jpg
# ✅ Downloaded Inspection Report for DG64XGK
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_8.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_8.jpg
# ✅ Downloaded Other Report for DG64XGK
# Watermark added to Images\EA17HKK\Original_images\EA17HKK_9.jpg
# Downloaded: Images\EA17HKK\Original_images\EA17HKK_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/55276bfe-457d-49fc-96a9-dd72abc871bf_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/08efd009-75a0-45da-bf5f-c2c321098095_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/fdea5daf-c6ad-4cdb-9afb-0a1c2b143488_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/4286c025-98d4-4149-8788-dac505598c57_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/277b2edd-285e-444d-8567-d36d0e231f4c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/c08ab6d9-33a6-47eb-b38b-a0424555f870_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/3dacf80b-753e-44d2-8e1b-c21146ea008e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/3dacf80b-753e-44d2-8e1b-c21146ea008e_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/77e6f468-11a6-4368-b8cf-76af915ccb40_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/c6f7bef1-3964-4359-9cec-f946823996fe_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/2bb883cc-78e3-4ead-bfcc-a34ce9db9638_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/d9a443ee-6383-4d18-a416-6d68d0f3a0b9_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/35debb88-8487-4e4f-99aa-034c57a3f026_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/32173a5d-ff57-46f3-ac34-662c742d58db_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/c4c6ef3a-d562-4f7a-99b1-0ecfc075a9c2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/fe766928-ac85-4b62-8b8b-b65795355e00_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/ac3aed08-96c1-457a-ba9d-6293c3a91f0b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/bf62d7d5-46aa-4dec-becd-d2168bea9c0e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/bf62d7d5-46aa-4dec-becd-d2168bea9c0e_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/EA17HKK/2025-10-27/damage/bf62d7d5-46aa-4dec-becd-d2168bea9c0e_3.jpg?w=600']
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_1.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_1.jpg
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_2.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_2.jpg
# ✅ Downloaded Inspection Report for SF16HSB
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_3.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_3.jpg
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_4.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_4.jpg
# ✅ Downloaded Other Report for SF16HSB
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_5.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_5.jpg
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_6.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_6.jpg
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_7.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_7.jpg
# ✅ Downloaded Inspection Report for GY66ONZ
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_8.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_8.jpg
# Watermark added to Images\DU67TZV\Original_images\DU67TZV_9.jpg
# Downloaded: Images\DU67TZV\Original_images\DU67TZV_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/62f9ce43-c064-4578-b169-18b816eb27a2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/49aa0774-a119-46e0-9d44-18934c4698ff_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/5638d279-a77b-4595-b78c-6f284fafb7ca_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/915b6cc1-e1f2-4325-a28a-58f13defb86f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/f0212441-7d0a-44ea-b396-1b2cce3fbe5d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/34da37ee-70b8-4776-8ca4-a0f1ae8ca541_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/cd317100-6c1d-434d-9dfd-5546e60c38fd_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/46c814d1-54a6-47e2-9f01-175f1b0a8fd3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DU67TZV/2025-10-23/damage/76a46f98-8421-4ee2-8e63-edb09e89d471_1.jpg?w=600']
# ✅ Downloaded Other Report for GY66ONZ
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_1.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_1.jpg
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_2.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_2.jpg
# ✅ Downloaded Inspection Report for KV18EHC
# ✅ Downloaded Other Report for KV18EHC
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_3.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_3.jpg
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_4.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_4.jpg
# ✅ Downloaded Inspection Report for LV10NBK
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_5.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_5.jpg
# ✅ Downloaded Other Report for LV10NBK
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_6.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_6.jpg
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_7.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_7.jpg
# ✅ Downloaded Inspection Report for YH11TKV
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_8.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_8.jpg
# ✅ Downloaded Other Report for YH11TKV
# Watermark added to Images\DG64XGK\Original_images\DG64XGK_9.jpg
# Downloaded: Images\DG64XGK\Original_images\DG64XGK_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/b2eacb1c-45b6-4279-ab7b-6e58dc83a9e1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/ce2e330d-003b-4bb5-94e3-8d3b6c5f9897_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/fd636da2-0bc0-4df9-aabf-9f33402e8c80_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/fd636da2-0bc0-4df9-aabf-9f33402e8c80_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/fd636da2-0bc0-4df9-aabf-9f33402e8c80_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/06a448e1-a627-460d-8ed3-db5d31c1ce9e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/8da09dca-6d90-40f6-b4a9-72dd23d72918_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/1b6ba0de-83fb-42cb-94b7-bbeb18a5626c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/3986fdf8-18df-477f-90e7-2ab1f587ef6b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/7c7b5333-084c-4aa6-946f-06ea25828f0e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/23edf05a-7cd8-4084-8ca2-90093a5b3ff6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/67d812b2-cc8b-4b86-9a37-a186d434c6b5_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/1b6571f8-ca79-4a85-a34e-2c9f8439e970_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/20befc65-5804-4695-9636-c97666897b6b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DG64XGK/2025-10-23/damage/32f704d4-1d5f-4753-8a10-ce7d93e0ecad_1.jpg?w=600']
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_1.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_1.jpg
# ✅ Downloaded Inspection Report for YC62FXR
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_2.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_2.jpg
# ✅ Downloaded Other Report for YC62FXR
# ✅ Downloaded Inspection Report for PL15EGK
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_3.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_3.jpg
# ✅ Downloaded Other Report for PL15EGK
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_4.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_4.jpg
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_5.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_5.jpg
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_6.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_6.jpg
# ✅ Downloaded Inspection Report for W66NGS
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_7.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_7.jpg
# ✅ Downloaded Other Report for W66NGS
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_8.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_8.jpg
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_9.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_9.jpg
# ✅ Downloaded Inspection Report for PK70EJG
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_10.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_10.jpg
# ✅ Downloaded Other Report for PK70EJG
# Watermark added to Images\SF16HSB\Original_images\SF16HSB_11.jpg
# Downloaded: Images\SF16HSB\Original_images\SF16HSB_11.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/6989145a-ca5b-4c1f-8489-9b012b04499c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/3f967ed0-48c2-4340-9e43-5e07302d8b8f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/8367f5af-9d48-47e9-999d-8224c1b44ae4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/914a595c-2fd7-4097-a707-2086a9165202_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/a80c67df-bd28-40e0-a17f-d674b7733e4c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/c3721e44-73da-41a6-90ab-f9980c972e78_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/a7fc541c-572f-404d-8949-48d8174ca79d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/c48553fe-327f-48f5-8ef0-57e3ddebf383_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/9c646cf9-1b42-4bb6-9db1-084cce90740a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/11f435ea-057e-471e-bbc8-aad1cb5ea0e2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/fae7b5dd-3838-45c9-bef4-67c77db20e20_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/691e08ef-086a-4b28-8dd5-91997f757052_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/f46f3d94-05c6-462e-a2b8-26d1224299fa_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/28c4c229-e894-4f1b-8692-a000645ae61d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/5a885d9c-bc07-4c9f-bf7f-1afd20a32bda_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SF16HSB/2025-10-17/damage/134bc8ce-8dd2-4ff0-9c67-c6598f0d99c5_1.jpg?w=600']
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_1.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_1.jpg
# ✅ Downloaded Inspection Report for PL16JJV
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_2.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_2.jpg
# ✅ Downloaded Other Report for PL16JJV
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_3.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_3.jpg
# ✅ Downloaded Inspection Report for PO13XPA
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_4.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_4.jpg
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_5.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_5.jpg
# ✅ Downloaded Other Report for PO13XPA
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_6.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_6.jpg
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_7.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_7.jpg
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_8.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_8.jpg
# Watermark added to Images\GY66ONZ\Original_images\GY66ONZ_9.jpg
# Downloaded: Images\GY66ONZ\Original_images\GY66ONZ_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/75c05c9b-a6d7-49b6-9b79-bad989bbb7f1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/725a3db1-5831-4013-ae1c-35173dc54955_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/725a3db1-5831-4013-ae1c-35173dc54955_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/725a3db1-5831-4013-ae1c-35173dc54955_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/554cd079-0cef-4b13-b1fa-8c9015830e2f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/1671f283-202f-4bbe-8c46-ef8a59a40ff1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/93107a2b-c9ab-4854-9759-b8b91c64592f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/056df5fe-4b27-4856-8d14-cc7987f90f76_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/0e5b7751-4391-4dcd-ae35-f2263bde8038_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/0e5b7751-4391-4dcd-ae35-f2263bde8038_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/efd07330-81d4-4def-8391-55037f461471_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/fb64ce65-c973-41d9-b82b-ba61a6bdb344_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/GY66ONZ/2025-10-23/damage/68967803-dabb-4804-8b1c-30bcf1c25d28_1.jpg?w=600']
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_1.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_1.jpg
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_2.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_2.jpg
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_3.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_3.jpg
# ✅ Downloaded Inspection Report for MM15UWO
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_4.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_4.jpg
# ✅ Downloaded Other Report for MM15UWO
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_5.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_5.jpg
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_6.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_6.jpg
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_7.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_7.jpg
# ✅ Downloaded Inspection Report for RE15HKF
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_8.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_8.jpg
# Watermark added to Images\KV18EHC\Original_images\KV18EHC_9.jpg
# Downloaded: Images\KV18EHC\Original_images\KV18EHC_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/be53b948-4869-4602-9bb2-a0d3bf268785_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/315ceef8-ceab-4d30-bd96-039c7605fe42_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/7f8c811b-e4ee-47c4-bd1b-d6e98fcd77dd_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/9300050e-bec0-4d89-909c-e8815b435c77_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/ec1e263e-8094-483b-b2ef-b3c33f95a0bd_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/5f1a1dbc-871e-47a4-baa2-22cd2f81ca38_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/d8c116b6-a718-4e76-98ce-88f66c5f7190_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/790c101d-7b08-4173-b86d-a37c9605aec4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/7d4ea0fd-2a37-4ab7-afb8-01d8063c6a82_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/36a480ba-00de-460b-8f1e-ac4831f8b3cd_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/2a7e54ce-5f82-4de1-aa20-3d56aec8a9bf_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/8f4ab3e5-7689-4662-a2ed-64e8cee65fd6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/40959c09-8db2-4636-9cb7-ea5c1ddefaca_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/7c9dae47-5ec2-4aab-94cb-7eac349c2ce4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KV18EHC/2025-10-21/damage/3212c3fa-e93c-45de-8cfa-fce86cfbbb60_1.jpg?w=600']
# ✅ Downloaded Other Report for RE15HKF
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_1.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_1.jpg
# ✅ Downloaded Inspection Report for GF62OPO
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_2.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_2.jpg
# ✅ Downloaded Other Report for GF62OPO
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_3.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_3.jpg
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_4.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_4.jpg
# ✅ Downloaded Inspection Report for SN63OCL
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_5.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_5.jpg
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_6.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_6.jpg
# ✅ Downloaded Other Report for SN63OCL
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_7.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_7.jpg
# Watermark added to Images\LV10NBK\Original_images\LV10NBK_8.jpg
# Downloaded: Images\LV10NBK\Original_images\LV10NBK_8.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_1.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_1.jpg
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_2.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_2.jpg
# ✅ Downloaded Inspection Report for DA13WNL
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_3.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_3.jpg
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_4.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_4.jpg
# ✅ Downloaded Other Report for DA13WNL
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_5.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_5.jpg
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_6.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_6.jpg
# Watermark added to Images\YH11TKV\Original_images\YH11TKV_7.jpg
# Downloaded: Images\YH11TKV\Original_images\YH11TKV_7.jpg
# Invalid URL skipped: https:///[]
# ✅ Downloaded Inspection Report for YH11FKN
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_1.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_1.jpg
# ✅ Downloaded Other Report for YH11FKN
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_2.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_2.jpg
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_3.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_3.jpg
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_4.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_4.jpg
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_5.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_5.jpg
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_6.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_6.jpg
# ✅ Downloaded Inspection Report for LR67OFU
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_7.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_7.jpg
# Watermark added to Images\YC62FXR\Original_images\YC62FXR_8.jpg
# Downloaded: Images\YC62FXR\Original_images\YC62FXR_8.jpg
# Invalid URL skipped: https:///[]
# ✅ Downloaded Other Report for LR67OFU
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_1.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_1.jpg
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_2.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_2.jpg
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_3.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_3.jpg
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_4.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_4.jpg
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_5.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_5.jpg
# ✅ Downloaded Inspection Report for SF11PMV
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_6.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_6.jpg
# ✅ Downloaded Other Report for SF11PMV
# Watermark added to Images\PL15EGK\Original_images\PL15EGK_7.jpg
# Downloaded: Images\PL15EGK\Original_images\PL15EGK_7.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\W66NGS\Original_images\W66NGS_1.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_1.jpg
# Watermark added to Images\W66NGS\Original_images\W66NGS_2.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_2.jpg
# ✅ Downloaded Inspection Report for LM62DGO
# Watermark added to Images\W66NGS\Original_images\W66NGS_3.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_3.jpg
# Watermark added to Images\W66NGS\Original_images\W66NGS_4.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_4.jpg
# ✅ Downloaded Other Report for LM62DGO
# Watermark added to Images\W66NGS\Original_images\W66NGS_5.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_5.jpg
# Watermark added to Images\W66NGS\Original_images\W66NGS_6.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_6.jpg
# Watermark added to Images\W66NGS\Original_images\W66NGS_7.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_7.jpg
# Watermark added to Images\W66NGS\Original_images\W66NGS_8.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_8.jpg
# ✅ Downloaded Inspection Report for BL15NXO
# Watermark added to Images\W66NGS\Original_images\W66NGS_9.jpg
# Downloaded: Images\W66NGS\Original_images\W66NGS_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/964e6389-555c-4040-8e5a-39bb4e15d63e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/51e267aa-21fd-4bc9-91cb-b3b060c78588_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/51e267aa-21fd-4bc9-91cb-b3b060c78588_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/23e7ff28-094e-4915-aba1-c784e6fbcc16_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/91124d62-2798-4bb0-a8e4-6ee84f844670_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/fe7e6533-9843-40a7-b5ca-e3608b5b7488_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/fe7e6533-9843-40a7-b5ca-e3608b5b7488_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/8ff294db-4a5e-490e-b093-a89c4c49674a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/4b631437-1d88-45df-b7cd-3822bfe04e24_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/4a678ca7-53e4-4f98-9cb0-19d34b5e4f55_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/4a678ca7-53e4-4f98-9cb0-19d34b5e4f55_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/4a678ca7-53e4-4f98-9cb0-19d34b5e4f55_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/940baf57-bb92-4fa9-8a4a-0ca7aa5affe6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/2a38feaf-a7d7-4d42-9ffb-1018d0f8b26c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/52cd9695-68a5-41c0-9a9a-47d59441deaf_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/W66NGS/2025-10-20/damage/c8f002a9-7af6-45c8-8bb0-a174bad1d1fd_1.jpg?w=600']
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_1.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_1.jpg
# ✅ Downloaded Other Report for BL15NXO
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_2.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_2.jpg
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_3.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_3.jpg
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_4.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_4.jpg
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_5.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_5.jpg
# ✅ Downloaded Inspection Report for SG61OSZ
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_6.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_6.jpg
# ✅ Downloaded Other Report for SG61OSZ
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_7.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_7.jpg
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_8.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_8.jpg
# ✅ Downloaded Inspection Report for BL07KWR
# Watermark added to Images\PK70EJG\Original_images\PK70EJG_9.jpg
# Downloaded: Images\PK70EJG\Original_images\PK70EJG_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/acbdd5de-e264-43ef-9df1-5c7c78baaeb4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/4af44bd6-6296-4f40-bd14-b7f828ce5708_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/cb33c414-dc42-41e7-bbd1-478b7d9cf7a3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/be9c7695-bda4-4a80-ba4f-9b41326e6a6a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/be5f2922-7122-4d5e-87f8-ba74d61975ff_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/e0578f9d-8bf8-433f-b4cc-849464db82ca_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/PK70EJG/2025-10-20/damage/e080a256-e593-48ba-acc5-479463b88dd6_1.jpg?w=600']
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_1.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_1.jpg
# ✅ Downloaded Other Report for BL07KWR
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_2.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_2.jpg
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_3.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_3.jpg
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_4.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_4.jpg
# ✅ Downloaded Inspection Report for EY64EHE
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_5.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_5.jpg
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_6.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_6.jpg
# ✅ Downloaded Other Report for EY64EHE
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_7.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_7.jpg
# Watermark added to Images\PL16JJV\Original_images\PL16JJV_8.jpg
# Downloaded: Images\PL16JJV\Original_images\PL16JJV_8.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_1.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_1.jpg
# ✅ Downloaded Inspection Report for CF14FSP
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_2.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_2.jpg
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_3.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_3.jpg
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_4.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_4.jpg
# ✅ Downloaded Other Report for CF14FSP
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_5.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_5.jpg
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_6.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_6.jpg
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_7.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_7.jpg
# ✅ Downloaded Inspection Report for KR14XCT
# ✅ Downloaded Other Report for KR14XCT
# Watermark added to Images\PO13XPA\Original_images\PO13XPA_8.jpg
# Downloaded: Images\PO13XPA\Original_images\PO13XPA_8.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_1.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_1.jpg
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_2.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_2.jpg
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_3.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_3.jpg
# ✅ Downloaded Inspection Report for SB67JJK
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_4.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_4.jpg
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_5.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_5.jpg
# ✅ Downloaded Other Report for SB67JJK
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_6.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_6.jpg
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_7.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_7.jpg
# Watermark added to Images\MM15UWO\Original_images\MM15UWO_8.jpg
# Downloaded: Images\MM15UWO\Original_images\MM15UWO_8.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_1.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_1.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_2.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_2.jpg
# ✅ Downloaded Inspection Report for MC18KPX
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_3.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_3.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_4.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_4.jpg
# ✅ Downloaded Other Report for MC18KPX
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_5.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_5.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_6.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_6.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_7.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_7.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_8.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_8.jpg
# ✅ Downloaded Inspection Report for SN66VBD
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_9.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_9.jpg
# Watermark added to Images\RE15HKF\Original_images\RE15HKF_10.jpg
# Downloaded: Images\RE15HKF\Original_images\RE15HKF_10.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/bafb65e8-03ee-426b-bb9e-51da0bb68a89_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/bafb65e8-03ee-426b-bb9e-51da0bb68a89_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/73a8166b-c109-4bb1-9097-bb6e97d073ca_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/73a8166b-c109-4bb1-9097-bb6e97d073ca_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/6669c6a8-71f4-4457-8934-2b759d91820a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/80fdc9ea-3389-4990-974c-3bb17355ede6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/80fdc9ea-3389-4990-974c-3bb17355ede6_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/d31f3178-f7bf-4c06-a19b-e1e95441e253_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/58ad66a7-4832-46b6-ad6e-e6d56a4c09b5_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/fb8e00e8-6aef-4fae-a574-163d80c47ad7_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/1b8ad499-55b9-40f0-b03d-903fff55f471_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/b71ceb77-13e4-4a00-832a-14b675da65cc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/80af13c5-1ba6-4e2c-aae6-ef0c1f81749a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/fac12a65-aa42-4bcd-bcc5-582d16e4d62a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/8c08fbfc-4072-4391-9b54-a400e0107034_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/93e8c4f3-d07c-4162-bc82-821648fa540b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/cbbcc289-2630-4739-b49c-32bff937c602_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/45d69582-b450-4b09-a4fc-6a88ddfe1dbb_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/4db2c5fc-5914-4464-9999-565fc4a91ede_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/c4ca18f9-9a50-40d8-8168-bb6d535fd5cf_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/RE15HKF/2025-10-06/damage/e2fc91a3-ccc4-4b64-a769-788b5eb31c62_1.jpg?w=600']
# ✅ Downloaded Other Report for SN66VBD
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_1.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_1.jpg
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_2.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_2.jpg
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_3.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_3.jpg
# ✅ Downloaded Inspection Report for PN13GMZ
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_4.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_4.jpg
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_5.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_5.jpg
# ✅ Downloaded Other Report for PN13GMZ
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_6.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_6.jpg
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_7.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_7.jpg
# Watermark added to Images\GF62OPO\Original_images\GF62OPO_8.jpg
# Downloaded: Images\GF62OPO\Original_images\GF62OPO_8.jpg
# Invalid URL skipped: https:///[]
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_1.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_1.jpg
# ✅ Downloaded Inspection Report for SP13WUC
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_2.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_2.jpg
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_3.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_3.jpg
# ✅ Downloaded Other Report for SP13WUC
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_4.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_4.jpg
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_5.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_5.jpg
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_6.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_6.jpg
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_7.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_7.jpg
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_8.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_8.jpg
# ✅ Downloaded Inspection Report for LV58XAL
# Watermark added to Images\SN63OCL\Original_images\SN63OCL_9.jpg
# Downloaded: Images\SN63OCL\Original_images\SN63OCL_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/f743903a-3f1a-42ee-9087-c749600770cb_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/95de3896-308d-4af0-b6f9-48c18e8f64ea_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/b2c2fd8e-6cf6-45bf-a9fa-ee49f5e5c751_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/9339d776-04bc-49dc-b8f7-b71ab159a9e3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/80c30d7c-efc8-4dd0-91c5-f5655e0440e1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/c53b98cd-1646-40f9-8676-ab777c9e4568_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/9f5ff79d-c4b4-4a88-a884-264dd180601b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/cabe366f-3056-444b-942a-2c72bcc11651_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/18e52178-4337-4d46-baff-795db0c51c52_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/c3947fa7-25a4-46fe-a775-ef21afa84645_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/0135fe4a-b7e1-42c1-98de-a8258e57e82f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/d212601a-345f-4893-a753-aeeb591be41a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/fd598a33-cc9c-4d99-9332-de31b56bf2bc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/bb1c981d-e848-418e-abd3-4a3f87029a40_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/15f10d48-241b-4834-b940-63d251e31268_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/51c755c5-7db4-4357-bbae-a6ae2bdbf9b9_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/b1b065e0-5ae0-4f36-9d71-661951848fa2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/61c93005-ca7e-425c-afd3-67ebcd79f605_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/567a312a-46d0-40d8-81f9-b371e5fd1798_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/7bb8003b-e821-4072-8f59-bd90f4cd6bdb_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/7eaa5817-1204-4a35-b6d8-00a6fb1a7b95_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/c1875aa8-cb22-42ab-9787-b661eb9b20df_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/1f71ba47-3e9b-4dbe-be03-466488de7f7d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/190665c2-eed6-4779-9212-8d1d30e12897_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/SN63OCL/2025-10-27/damage/15be8536-2624-4ee3-b355-cdbb0bb72368_1.jpg?w=600']
# ✅ Downloaded Other Report for LV58XAL
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_1.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_1.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_2.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_2.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_3.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_3.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_4.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_4.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_5.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_5.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_6.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_6.jpg
# ✅ Downloaded Inspection Report for SW10HFX
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_7.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_7.jpg
# ✅ Downloaded Other Report for SW10HFX
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_8.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_8.jpg
# Watermark added to Images\DA13WNL\Original_images\DA13WNL_9.jpg
# Downloaded: Images\DA13WNL\Original_images\DA13WNL_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/ca1abc61-82f6-47a4-8554-6f002dd2710c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/e64502b8-e018-4948-9cae-02cfedbd631b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/af48ba35-7fbe-4c56-a4e7-c583d463aed9_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/dc4b6e6c-4a55-4acb-8366-5b0aae71d512_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/dc4b6e6c-4a55-4acb-8366-5b0aae71d512_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/dc4b6e6c-4a55-4acb-8366-5b0aae71d512_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/3a6c7919-996f-4557-966a-f4d022e122c2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/625ba937-aa3a-4582-af34-b6b531bc6bef_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/c5ed098a-560e-4d5d-ae41-23d94a60c4e0_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/3dbdbf4d-c53f-41a9-93fe-52c576c3ca8a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/94ce1b5f-1533-434b-bfcf-55eab479150b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/1a95b1e5-acfa-4800-b301-d5ebda545a3f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/75749eaa-6865-4676-b9c9-544d83a8fdc6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/47c489a9-4adb-4fe0-ba2a-fbf1402c20cc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/b823cdcd-3d89-4123-b738-61f396d96332_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/e67f5a16-2a20-4a14-af3d-56747fa573e1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/191fd7a5-01c4-4559-876c-f58de47693cc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/764a09bf-073b-4f26-8bc6-0b2962c9ce4e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/223a5c80-8c7d-46d6-8536-6c6e70d1f359_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/f4f02576-eefe-434b-ab2a-ab5af9cf2caf_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/f411ae96-16d8-475d-9276-1e9ee692cb85_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/94f2ffa0-8143-4884-b467-0d4a41d61c89_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/9e99edb1-d197-4f06-b443-06419aa69dfc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/0479932f-3ed2-4f68-94c4-1e3ed2ade4f9_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/DA13WNL/2025-10-21/damage/44239232-8a47-4fe4-b8a7-343c3cd0f0f9_1.jpg?w=600']
# ✅ Downloaded Inspection Report for PK66HVE
# Watermark added to Images\YH11FKN\Original_images\YH11FKN_1.jpg
# Downloaded: Images\YH11FKN\Original_images\YH11FKN_1.jpg
# ✅ Downloaded Other Report for PK66HVE
# Watermark added to Images\YH11FKN\Original_images\YH11FKN_2.jpg
# Downloaded: Images\YH11FKN\Original_images\YH11FKN_2.jpg
# Watermark added to Images\YH11FKN\Original_images\YH11FKN_3.jpg
# Downloaded: Images\YH11FKN\Original_images\YH11FKN_3.jpg
# Watermark added to Images\YH11FKN\Original_images\YH11FKN_4.jpg
# Downloaded: Images\YH11FKN\Original_images\YH11FKN_4.jpg
# ✅ Downloaded Inspection Report for NA13CPY
# Watermark added to Images\YH11FKN\Original_images\YH11FKN_5.jpg
# Downloaded: Images\YH11FKN\Original_images\YH11FKN_5.jpg
# ✅ Downloaded Other Report for NA13CPY
# ...
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_5.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_5.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_6.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_6.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_7.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_7.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_8.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_8.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_9.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_9.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_10.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_10.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_11.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_11.jpg
# Watermark added to Images\NX69GCZ\Original_images\NX69GCZ_12.jpg
# Downloaded: Images\NX69GCZ\Original_images\NX69GCZ_12.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/4ac7fed6-5c79-4552-b730-be611b38983a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/4816eb5f-71bb-4a2e-a780-1b0c838efb5f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/97b6f5ca-33fe-4f27-8a2b-f5b88d80a4ae_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/00b80d16-eca5-4cef-a550-bde0f2453a1a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/4ea3ab5d-43f7-41b6-87d5-0017a134e492_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/c9476079-6e2a-41e0-846b-43c6e9084cbd_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/0c7d3441-5b22-4fd3-8cc8-815ee4c5d2c6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/34773104-c54a-4260-bb8c-b5e1e2aeb04c_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/cfb3993c-d66a-412b-8a91-433c60849015_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/96764399-2fc0-4a1d-b64e-6622afd1e383_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/96764399-2fc0-4a1d-b64e-6622afd1e383_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/0f04b668-64cc-48a0-b3fe-3b0d0b890e8b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/0f04b668-64cc-48a0-b3fe-3b0d0b890e8b_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/184c7a7f-f210-4e7c-a3b9-ad9e98ed9ca1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/184c7a7f-f210-4e7c-a3b9-ad9e98ed9ca1_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/1b39d2d4-d1eb-418a-bbc8-572800931e24_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/fb92819c-cd86-46d3-8cc3-37dce916c4a2_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/b9448569-af36-4981-8815-a540326d78b4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/b9448569-af36-4981-8815-a540326d78b4_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/bfe76a14-422b-46c9-b247-7444b7531cb3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/bb15ef09-16fd-48d4-9980-c49ef23d6822_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/bb15ef09-16fd-48d4-9980-c49ef23d6822_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/ce697d1c-7e77-4a22-90b0-df8cf9cc522a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/d88fddf6-6186-4a04-80de-369678e62cc4_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/f899e465-88e6-4fca-95c8-51f6925e92dc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/2cbe56da-0198-40d6-aa4a-e9426968e05a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/NX69GCZ/2025-10-20/damage/2cbe56da-0198-40d6-aa4a-e9426968e05a_2.jpg?w=600']
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_1.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_1.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_2.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_2.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_3.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_3.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_4.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_4.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_5.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_5.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_6.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_6.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_7.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_7.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_8.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_8.jpg
# Watermark added to Images\OY69RVL\Original_images\OY69RVL_9.jpg
# Downloaded: Images\OY69RVL\Original_images\OY69RVL_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/befab0fe-131f-4ab8-bed3-39b182f387c1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/543abdc9-fb0b-4ec0-a28f-d594ee797aac_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/857e64cf-db6d-462b-834e-781151932ad6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/803f80af-79f3-4341-9839-01c19c32129d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/8c4a1a63-8d04-4532-8780-d0cfbb3f73d3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/8c4a1a63-8d04-4532-8780-d0cfbb3f73d3_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/53f99802-a3eb-4a90-94b9-86f25f3880de_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/d5935da0-72de-4886-bb51-bbbaed73b615_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/d5935da0-72de-4886-bb51-bbbaed73b615_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OY69RVL/2025-09-24/damage/c76eb783-4956-4707-a22d-240fd2628c1d_1.jpg?w=600']
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_1.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_1.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_2.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_2.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_3.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_3.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_4.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_4.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_5.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_5.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_6.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_6.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_7.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_7.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_8.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_8.jpg
# Watermark added to Images\OV70KOW\Original_images\OV70KOW_9.jpg
# Downloaded: Images\OV70KOW\Original_images\OV70KOW_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/OV70KOW/2025-09-12/damage/b5766776-69f8-4449-9ffe-9cdc28bf3dcc_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OV70KOW/2025-09-12/damage/e47bfe9e-5a7e-4a64-9afd-1b0787a5cc39_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OV70KOW/2025-09-12/damage/636f8986-9d59-4a37-9ee9-2763f967478f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OV70KOW/2025-09-12/damage/af3371d0-bfde-4b60-9538-3b33f73fefd7_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/OV70KOW/2025-09-12/damage/1a3577dc-afa9-45d3-bf3a-e3abee27b007_1.jpg?w=600']
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_1.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_1.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_2.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_2.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_3.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_3.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_4.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_4.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_5.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_5.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_6.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_6.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_7.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_7.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_8.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_8.jpg
# Watermark added to Images\KM65ZJN\Original_images\KM65ZJN_9.jpg
# Downloaded: Images\KM65ZJN\Original_images\KM65ZJN_9.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/d30053e0-10f7-4a2d-adde-e507ad069c56_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/d30053e0-10f7-4a2d-adde-e507ad069c56_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/d30053e0-10f7-4a2d-adde-e507ad069c56_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/e82c6ce2-a7d9-4943-a0a3-30fb0a9ba150_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/612f45e9-c167-471d-b470-7afe1e8cb1f6_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/f33fe8b1-8265-4361-a060-08cccee0e604_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/1d5343eb-5fb4-4b12-870d-dae7f0a1bfe5_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/82bc3bdf-c438-4dff-932f-5a042d74b6e3_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/5355f654-424f-4648-add1-8d764261829d_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/d968f9c9-ff73-40b9-8d95-082c42c040d0_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/a5c97131-dfd9-4aea-9e5f-f56be0573134_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/b28bec22-d666-4695-9c8d-45b8764cfb95_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/07accf52-b507-452b-a36f-8b0c2887eaf9_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/b2688a7d-7ebf-40d1-904e-ee4032600260_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/741b49d0-b46e-48a8-89d9-ec773392ebab_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/f3a2594d-0429-43d3-a87c-70347756ac3a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/fc5500ff-acdc-423a-910b-d7565880ee81_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KM65ZJN/2025-10-10/damage/b5238e11-6f54-486f-a0d6-7bfa0f9a45e4_1.jpg?w=600']
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_1.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_1.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_2.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_2.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_3.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_3.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_4.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_4.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_5.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_5.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_6.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_6.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_7.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_7.jpg
# Watermark added to Images\KW65KMM\Original_images\KW65KMM_8.jpg
# Downloaded: Images\KW65KMM\Original_images\KW65KMM_8.jpg
# Invalid URL skipped: https:///['https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/32640024-6a54-4516-a07f-b4548adc8c3f_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/81889954-1fb5-4c2d-aced-da8c10628b6e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/d9c44fb8-e08a-4681-b6de-04f78993d786_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/efcbb5c4-27a4-4b77-aff7-8c08af827a3e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/efcbb5c4-27a4-4b77-aff7-8c08af827a3e_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/626bb863-9858-4189-a67f-01decdf815d1_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/1fd4fdac-dc99-4a38-84f9-fcded45085e5_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/ce1f13bc-4ce3-46e0-85b9-eaa24a512275_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/f7ec491b-3fad-4b1f-b15d-f843b9211e4a_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/f7ec491b-3fad-4b1f-b15d-f843b9211e4a_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/f7ec491b-3fad-4b1f-b15d-f843b9211e4a_3.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/55d20c57-ae93-4973-b7c6-40ce7a765f96_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/53f163ad-ce91-47a1-ae44-d8c0b1e357ff_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/53f163ad-ce91-47a1-ae44-d8c0b1e357ff_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/bafb6b5d-880d-416e-910b-fec73480587e_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/55646b93-f846-4eb3-850c-b8cfc8ea874b_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/55646b93-f846-4eb3-850c-b8cfc8ea874b_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/df9d190a-59cf-46af-9fdc-fb17917855f8_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/a370872a-522c-4cac-afbd-b93ef7649721_1.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/a370872a-522c-4cac-afbd-b93ef7649721_2.jpg?w=600'
# Invalid URL skipped: https:///'https:/abimg003.imgix.net/KW65KMM/2025-06-16/damage/4f412b60-9ebf-485c-a08a-77ca8147fa11_1.jpg?w=600']
