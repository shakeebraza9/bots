# %%
import pandas as pd

data = [
    {
        "Unnamed: 0": 851,
        "Reg": "LS70 NLV",
        "VIN": "WAUZZZGY1MA032370",
        "Auction type": "Online Only",
        "Center": "Birmingham - Perry Barr",
        "Make": "AUDI",
        "Model": "A3 SPORTBACK",
        "Fuel Type": "Petrol",
        "Transmission": "Manual",
        "Mileage": 28557,
        "Year": 2020,
        "Colour": "BLACK",
        "Vehicle Age": "Shakeeb",
        "MOT Expiry Date": "2025-10-27",
    },
    {
        "Unnamed: 0": 718,
        "Reg": "RO71 GZM",
        "VIN": "WAUZZZGY4NA008646",
        "Auction type": "Online Only",
        "Center": "Manchester",
        "Make": "AUDI",
        "Model": "A3 SALOON",
        "Fuel Type": "Petrol",
        "Transmission": "Auto",
        "Mileage": 27654,
        "Year": 2021,
        "Colour": "BLACK",
        "Vehicle Age": "",
        "MOT Expiry Date": "2026-10-06",
    },
    {
        "Unnamed: 0": 70,
        "Reg": "HJ22 GKN",
        "VIN": "WAUZZZFZ6NP012382",
        "Auction type": "Online Only",
        "Center": "Bedford",
        "Make": "AUDI",
        "Model": "Q4 E-TRON",
        "Fuel Type": "Electric",
        "Transmission": "Automatic",
        "Mileage": 45937,
        "Year": 2022,
        "Colour": "BLUE",
        "Vehicle Age": "",
        "MOT Expiry Date": "2026-03-20",
    }
]

df = pd.DataFrame(data)
df.to_csv("test.csv", index=False)
print("✅ test.csv file created successfully!")
# Out:
# ✅ test.csv file created successfully!
